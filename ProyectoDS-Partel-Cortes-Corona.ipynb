# %% [markdown]
# - https://www.kaggle.com/competitions/home-credit-default-risk/data
# - https://github.com/YadielCortes/DataScience

# %% [markdown]
# ####El dataset que vamos a ocupar (BankChurners.csv) nos habla de un banco el cual nos da informacion sobre los clientes unas de las cosas quue resivimos es su estado civil, cuanto dinero percibe, su sexo, cuantas personas depende de el, su nivel de educacion, etc. por lo consecuente podemos hacer distintos analisis.
# - CLIENTNUM: Numero de cliente
# - Attrition_Flag: Variable de evento interno (actividad del cliente): si la cuenta está cerrada, entonces 1 o 0
# - Gender: Variable demográfica - M=Hombre, F=Mujer
# - Customer_Age: Edad
# - Dependent_count: Recuento de dependientes
# - Education_Level: Nivel de educación
# - Marital_Status: Estado civil
# - Income_Category: Salario que percibe
# - Card_Category: Categoria de targeta (Blue, Silver, Gold, Platinum)
# - Months_on_book: Periodo con relacion con el banco
# - Total_Relationship_Count: Número total de productos en poder del cliente
# - Months_Inactive_12_mon: Nº de meses inactivos en los últimos 12 meses
# - Contacts_Count_12_mon: Nº de Contactos en los últimos 12 meses
# - Credit_Limit: Límite de crédito en la tarjeta de crédito
# - Total_Revolving_Bal: Saldo rotatorio total de la tarjeta de crédito
# - Avg_Open_To_Buy: Línea de Crédito Abierta para Comprar (Promedio de los últimos 12 meses)
# - Total_Amt_Chng_Q4_Q1: Cambio en el monto de la transacción (cuarto trimestre respecto al primer trimestre)
# - Total_Trans_Amt: Monto total de la transacción (últimos 12 meses)
# - Total_Trans_Ct: Recuento total de transacciones (últimos 12 meses)
# - Total_Ct_Chng_Q4_Q1: Cambio en el recuento de transacciones (cuarto trimestre respecto al primer trimestre)
# - Avg_Utilization_Ratio: Índice de utilización promedio de la tarjeta

# %% [markdown]
# ##Hipotesis
# Analisando el dataset se puede decir que las personas que llegan a tener la targeta de mayor valor son personas grandes y esto se debe a que estas regularmente ya hicieron un historial crediticio pero esto puede tambien ser contrario ya que los bancos no se arriengan a prestale dinero a los que ya son muy mayores. Por  lo cual vamos a encontrar muy pocas personas que gosen de la mejor targeta pero vamos a encontar muchas personas que gosen de la de menor valor, y asi ira bajando.

# %% [markdown]
# ##Importancion de librerias

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mlp

# %%
url='https://raw.githubusercontent.com/YadielCortes/DataSciencie/main/BankChurners.csv'

# %%
url='https://raw.githubusercontent.com/YadielCortes/DataScience/main/Credit%20Card%20Eligibility%20Data%20Determining%20Factors.csv'

# %%
url='https://raw.githubusercontent.com/YadielCortes/DataScience/main/alzheimers_disease_data.csv'

# %% [markdown]
# ##Dataset lectura de dataset

# %%
Banco=pd.read_csv("https://raw.githubusercontent.com/YadielCortes/DataSciencie/main/BankChurners.csv")
Banco
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
Banco_elegibilidad=pd.read_csv("https://raw.githubusercontent.com/YadielCortes/DataScience/main/Credit%20Card%20Eligibility%20Data%20Determining%20Factors.csv")
Banco_elegibilidad
# Out:
#            ID  Gender  Own_car  Own_property  Work_phone  Phone  Email  \
# 0     5008804       1        1             1           1      0      0
# 1     5008806       1        1             1           0      0      0
# 2     5008808       0        0             1           0      1      1
# 3     5008812       0        0             1           0      0      0
# 4     5008815       1        1             1           1      1      1
# ...       ...     ...      ...           ...         ...    ...    ...
# 9704  5148694       0        0             0           0      0      0
# 9705  5149055       0        0             1           1      1      0
# 9706  5149729       1        1             1           0      0      0
# 9707  5149838       0        0             1           0      1      1
# 9708  5150337       1        0             1           0      0      0
#
#       Unemployed  Num_children  Num_family  Account_length  Total_income  \
# ...

# %%
alzheimers=pd.read_csv("https://raw.githubusercontent.com/YadielCortes/DataScience/main/alzheimers_disease_data.csv")
alzheimers
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0          4751   73       0          0               2  22.927749        0
# 1          4752   89       0          0               0  26.827681        0
# 2          4753   73       0          3               1  17.795882        0
# 3          4754   74       1          0               1  33.800817        1
# 4          4755   89       0          0               0  20.716974        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2144       6895   61       0          0               1  39.121757        0
# 2145       6896   75       0          0               2  17.857903        0
# 2146       6897   77       0          0               1  15.476479        0
# 2147       6898   78       1          3               1  15.299911        0
# 2148       6899   72       0          0               2  33.289738        0
#
# ...

# %% [markdown]
# ## Informacion y cambio de variables

# %%
Banco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
Banco.rename(columns={"Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1":"Naive_Bayes_1"},inplace=True)
Banco.rename(columns={"Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2":"Naive_Bayes_2"},inplace=True)

# %%
Banco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %%
Banco_elegibilidad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9709 entries, 0 to 9708
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               9709 non-null   int64
#  1   Gender           9709 non-null   int64
#  2   Own_car          9709 non-null   int64
#  3   Own_property     9709 non-null   int64
#  4   Work_phone       9709 non-null   int64
#  5   Phone            9709 non-null   int64
#  6   Email            9709 non-null   int64
#  7   Unemployed       9709 non-null   int64
#  8   Num_children     9709 non-null   int64
#  9   Num_family       9709 non-null   int64
#  10  Account_length   9709 non-null   int64
#  11  Total_income     9709 non-null   float64
#  12  Age              9709 non-null   float64
#  13  Years_employed   9709 non-null   float64
#  14  Income_type      9709 non-null   object
#  15  Education_type   9709 non-null   object
#  16  Family_status    9709 non-null   object
# ...

# %%
alzheimers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2149 entries, 0 to 2148
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PatientID                  2149 non-null   int64
#  1   Age                        2149 non-null   int64
#  2   Gender                     2149 non-null   int64
#  3   Ethnicity                  2149 non-null   int64
#  4   EducationLevel             2149 non-null   int64
#  5   BMI                        2149 non-null   float64
#  6   Smoking                    2149 non-null   int64
#  7   AlcoholConsumption         2149 non-null   float64
#  8   PhysicalActivity           2149 non-null   float64
#  9   DietQuality                2149 non-null   float64
#  10  SleepQuality               2149 non-null   float64
#  11  FamilyHistoryAlzheimers    2149 non-null   int64
#  12  CardiovascularDisease      2149 non-null   int64
# ...

# %% [markdown]
# ##Graficos

# %%
Banco
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
Banco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %% [markdown]
# ###Hipotesis
# Planteamos la pregunta cual es la edad de las personas que cuentan con la targeta platino y cuántas personas son?
# De primera podemos deducir que serán muy pocas personas las que cuenten con las mejores tarjetas gold y platino ya que los bancos no ofrecen mucho estas porque su mantenimiento es caro.

# %%
sns.displot(Banco, x='Customer_Age', hue='Card_Category', col='Card_Category',col_order=["Blue","Silver","Gold","Platinum"],binwidth=1)

# %%
Banco["Card_Category"].unique()
# Out:
# array(['Blue', 'Gold', 'Silver', 'Platinum'], dtype=object)

# %%
Banco_3 = Banco[["CLIENTNUM", "Card_Category"]].groupby("Card_Category").count()
Banco_3
# Out:
#                CLIENTNUM
# Card_Category
# Blue                9436
# Gold                 116
# Platinum              20
# Silver               555

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.pie(Banco_2["CLIENTNUM"], labels=Banco_3.index, autopct='%1.1f%%')
ax.set_title('Distribución de clientes por tarjeta')
#
# Out:
# Text(0.5, 1.0, 'Distribución de clientes por tarjeta')

# %%
sns.displot(Banco, x='Card_Category', hue='Income_Category', col='Income_Category', col_order=["Less than $40K","$40K - $60K","$60K - $80K","$80K - $120K","$120K +","Unknown"] ,binwidth=1)

# %% [markdown]
# Como se puede apreciar en las distintas gráficas y tabla podemos ver que son 20 personas la que cuentan  con la mayor tarjeta.

# %%
#female = Banco.loc[(Banco.Customer_Age.notnull())&(Banco['Gender']=="F"), 'Customer_Age']
#male = Banco.loc[(Banco.Customer_Age.notnull())&(Banco['Gender']=="M"), 'Customer_Age']

# Axes level
#import matplotlib.pyplot as plt
#f, axs = plt.subplots(1, 2, figsize=(15, 10), gridspec_kw=dict(width_ratios=[4, 3]))
#sns.scatterplot(data=Banco, x="Credit_Limit", y="Avg_Open_To_Buy", hue="Gender", ax=axs[0])
#sns.histplot(data=Banco, x="Gender", hue="Gender", shrink=.8, alpha=.8, legend=False, ax=axs[1])
#f.tight_layout()

# %% [markdown]
# ###Hipotesis
# Queremos saber cuantas personas estan graduadas y asi como cual es la cantidad de peronsas con los diferentes estudios y que tipo de targeta tienen. Si es como se ha estado checando la mayoria de las personas estaran en la primera targeta blue.

# %%
eje_x=Banco["Education_Level"].unique()#sorted es ordenar los valores (unique) es solo las clases que hay no todas sino solo las 3 que hay
eje_y=Banco.groupby("Education_Level").count()["CLIENTNUM"]

# %%
fig, ax = plt.subplots(figsize=(11, 9))
mlp.style.use('fivethirtyeight')
#ax.bar(eje_x, eje_y, color=["red", "green","blue"])
ax.bar(eje_x, eje_y)
ax.set_title('Cantidad de Clientes')
ax.set_xticks(eje_x)#ticks son los numeros que aparecen abajo 0.5, 1, 2 ,3 etc
ax.set_xlabel('Educacion')
ax.set_ylabel('Cantidad de Clientes')
# Out:
# Text(0, 0.5, 'Cantidad de Clientes')

# %%
Niveles=sns.displot(data=Banco, x='Education_Level', hue='Education_Level', col='Card_Category',col_order=["Blue","Silver","Gold","Platinum"], log_scale=10, binwidth=0.1)

# Girar las etiquetas del eje x
for ax in Niveles.axes.flat:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.show()
# Out:
# <ipython-input-25-7ef51e02f356>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

# %% [markdown]
# ###Hipotesis
# Nos hacemos la pregunta de cuantas personas gosan con las difentes targetas?
# y aqui nos preguntamos si la intitucion da siempre las targetas con menor valor o si cambiara algo en este dataset.

# %%
print(Banco.Card_Category.unique())
sns.countplot(data = Banco, x='Card_Category', order=['Blue', 'Silver', 'Gold', 'Platinum'], palette="YlGnBu" )



print(np.array(Banco.Card_Category.mode()))
print(np.array(Banco.Card_Category.value_counts())[0] / len(Banco))
# Out:
# ['Blue' 'Gold' 'Silver' 'Platinum']
# ['Blue']
# 0.931766564629209
# <ipython-input-26-1ac3e9c578be>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = Banco, x='Card_Category', order=['Blue', 'Silver', 'Gold', 'Platinum'], palette="YlGnBu" )

# %% [markdown]
# ###Hipotesis

# %%
#
print(Banco.Credit_Limit.min(), Banco.Credit_Limit.max())
sns.histplot(data=Banco, x='Credit_Limit', binrange=(0,35000), palette="YlGnBu", bins=21)


print(Banco[Banco.Credit_Limit > 33750].Credit_Limit.count())
print(Banco[Banco.Credit_Limit > 33750].Credit_Limit.count())#/ len(Banco)
# Out:
# 1438.3 34516.0
# 530
# 530
# <ipython-input-27-a7e4059a57d3>:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=Banco, x='Credit_Limit', binrange=(0,35000), palette="YlGnBu", bins=21)

# %%
import numpy as np
from bokeh.io import show, output_file
from bokeh.io import show, output_notebook
from bokeh.plotting import figure
from bokeh.models import HoverTool

output_notebook()

data = Banco.Customer_Age.values
data=data[~np.isnan(data)] # data = dataframe de edades sin datos nulos
hist, edges = np.histogram(data, density=False, bins=20)
p = figure(height=300,width=500, title='Histograma de edades')
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="white")
p.xaxis.axis_label = "Edad"
p.yaxis.axis_label = "Frecuencia"
p.add_tools(HoverTool())
#output_file("hist.html")
show(p)
# Out:
#   <div id="bebd88c7-ca9b-4b6f-a162-afb6dda1ab9c" data-root-id="p1001" style="display: contents;"></div>

# %% [markdown]
# ###Hipotesis
# Sera que el banco discrimina si es hombre o mujer?
# Podemos hacernos esta pregunta y sacar el dato para conocer cuantos hombres y mujeres cuentan con tarjeta aunque lo haremos pr medio de un boxplot y metindo las edades como comparativa aun asi con esto podemos saber si estan parejos o no.

# %%
female = Banco.loc[(Banco.Customer_Age.notnull())&(Banco['Gender']=="F"), 'Customer_Age']
male = Banco.loc[(Banco.Customer_Age.notnull())&(Banco['Gender']=="M"), 'Customer_Age']

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.boxplot(x=[male, female])
grupos = ['Hombres', 'Mujeres']
ax.set_title('Boxplot de edades de pasajeros')
ax.set_xlabel('Sexo')
ax.set_ylabel('Edad (Años)')
ax.set_xticklabels(grupos)
# Out:
# [Text(1, 0, 'Hombres'), Text(2, 0, 'Mujeres')]

# %% [markdown]
# ### Hipotesis
# Podemos poner en un grafico de pie cual es el porcentaje de estado civil de las personas, por lo concecuente podemos sacar una hipotesis; podemos esperar que ell mayor porcentaje lo tengan las personas quue estan casadas o solteras, ya que los bancos le dan las targetas a las personas que son compremetidas o que pueden llegar a deberle al banco ya que por los intereses ellos ganan

# %%
Banco["Marital_Status"].unique()
# Out:
# array(['Married', 'Single', 'Unknown', 'Divorced'], dtype=object)

# %%
Banco_2 = Banco[["CLIENTNUM", "Marital_Status"]].groupby("Marital_Status").count()
Banco_2
# Out:
#                 CLIENTNUM
# Marital_Status
# Divorced              748
# Married              4687
# Single               3943
# Unknown               749

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.pie(Banco_2["CLIENTNUM"], labels=Banco_2.index, autopct='%1.1f%%')
ax.set_title('Distribución de clientes por estado civsil')
#
# Out:
# Text(0.5, 1.0, 'Distribución de clientes por estado civsil')
